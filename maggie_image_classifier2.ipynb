# %%
# !pip install torchvision 
# !pip install kaggle kagglehub

# %%
import torch

import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.transforms import Resize, ToTensor, Normalize

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import kagglehub

import os

import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download("sudipde25/mri-dataset-for-detection-and-analysis")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /ccsopen/home/maggiemiller/.cache/kagglehub/datasets/sudipde25/mri-dataset-for-detection-and-analysis/versions/21

# %%
data_dr = path + "/NINS_Dataset/NINS_Dataset/"
os.listdir(data_dr)

# %%
# Path to your image file
image_path = data_dr + "Brain Infection/44101875.jpg" # or .png, .jpeg, etc.

# Open the image using PIL
img = Image.open(image_path)

# Display using matplotlib
plt.imshow(img)
plt.title("sick brainnn")
plt.axis('off')
plt.show()
